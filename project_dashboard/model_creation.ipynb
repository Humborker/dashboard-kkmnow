# %% [markdown]
# # Project Title: Prediction of COVID-19 Deaths and Cases
# Goal: To compare a traditional Machine Learning approach (Scikit-learn) with a Deep Learning approach (Keras) for predicting COVID-19 cases/deaths.
# Rationale: covid_deaths and covid_cases are the only two datasets within KKMNow that contain a detailed set of features against the target features. All other datasets contain a limited number of features to adequately perform machine learning using scikit or tensorflow.

# %% [markdown]
# *Covid Deaths*
# Model Name: covid_deaths
# Models Used: RandomForestClassifier
#
# Rationale: The Covid Deaths dataset had multiple time series features. A decision was made to not use the time series as target features for death and instead, drop them entirely. The RandomForestClassifier was chosen as the dataframe contained multipel categorical features.
#
# *Covid Cases*
# Model Name: covid_cases
#
# Models Used: XGBRegressor
#
# Rationale: The target is primarily a continuous numerical integer and has a strict linear relationship with most of the features. Therefore, XGBRegressor was chosen.

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import numpy
import seaborn as sns
import matplotlib
import joblib
from dataloader import load_project_data
import os

# %% [markdown]
# ## Data Loading

# %%
# path to all datasets
path = "../project_dashboard/datasets"
# loading datasets in a dictionary of dataframes for easier navigation.
if os.path.exists(path):
    df = load_project_data(path)

# %% [markdown]
# ### Initial Exploration and Data Loading

# %%
# Viewing all entries in dictionary
df.keys()
# Out:
# dict_keys(['covid_deaths_linelist', 'infant_immunisation', 'pekab40_screenings_state', 'blood_donations_state', 'covid_cases', 'covid_cases_age', 'blood_donations'])

# %%
print(f"Covid Deaths: {df['covid_deaths_linelist'].size}")
print(f"Covid Deaths: {df['covid_cases'].size}")
# Out:
# Covid Deaths: 560265
# Covid Deaths: 232526

# %%
# Shape of dataframes
for key in df.keys():
    print(key)
    print(f"Size of Dataframe:{df[key].shape}")
# Out:
# covid_deaths_linelist
# Size of Dataframe:(37351, 15)
# infant_immunisation
# Size of Dataframe:(120, 3)
# pekab40_screenings_state
# Size of Dataframe:(40416, 3)
# blood_donations_state
# Size of Dataframe:(479570, 4)
# covid_cases
# Size of Dataframe:(33218, 7)
# covid_cases_age
# Size of Dataframe:(33218, 16)
# blood_donations
# Size of Dataframe:(36890, 3)

# %%
# Conversion to singular dataframes for covid_deaths and covid_cases and refactoring of variable names.
# Infant immunisation, pekab40_screening, blood donation and blood doantions were ignored due to lack of features
covid_deaths = df["covid_deaths_linelist"]
covid_cases = df["covid_cases"]

# %%
covid_cases.head()
# Out:
#          date     state  cases_new  cases_import  cases_recovered  \
# 0  2020-01-25  Malaysia          4             4                0
# 1  2020-01-26  Malaysia          0             0                0
# 2  2020-01-27  Malaysia          0             0                0
# 3  2020-01-28  Malaysia          0             0                0
# 4  2020-01-29  Malaysia          3             3                0
#
#    cases_active  cases_cluster
# 0             4              0
# 1             4              0
# 2             4              0
# 3             4              0
# 4             7              0

# %%
covid_deaths.head()
# Out:
#          date date_announced date_positive date_dose1 date_dose2 date_dose3  \
# 0  2020-03-17     2020-03-17    2020-03-12        NaN        NaN        NaN
# 1  2020-03-17     2020-03-17    2020-03-15        NaN        NaN        NaN
# 2  2020-03-20     2020-03-20    2020-03-11        NaN        NaN        NaN
# 3  2020-03-21     2020-03-21    2020-03-13        NaN        NaN        NaN
# 4  2020-03-22     2020-03-22    2020-03-20        NaN        NaN        NaN
#
#   brand1 brand2 brand3    state  age  male  bid  malaysian  comorb
# 0    NaN    NaN    NaN    Johor   34     1    0          1       1
# 1    NaN    NaN    NaN  Sarawak   60     1    0          1       1
# 2    NaN    NaN    NaN    Sabah   58     1    0          1       1
# 3    NaN    NaN    NaN   Melaka   50     1    0          1       1
# 4    NaN    NaN    NaN  Sarawak   80     0    1          1       1

# %% [markdown]
# ### Data Preprocessing

# %%
# Determination of number of unique states
print(f"{covid_cases['state'].unique()}")
print(f"{covid_deaths['state'].unique()}")
# Out:
# ['Malaysia' 'Johor' 'Kedah' 'Kelantan' 'Melaka' 'Negeri Sembilan' 'Pahang'
#  'Perak' 'Perlis' 'Pulau Pinang' 'Sabah' 'Sarawak' 'Selangor' 'Terengganu'
#  'W.P. Kuala Lumpur' 'W.P. Labuan' 'W.P. Putrajaya']
# ['Johor' 'Sarawak' 'Sabah' 'Melaka' 'W.P. Kuala Lumpur' 'Kelantan'
#  'Perlis' 'Pulau Pinang' 'Selangor' 'Kedah' 'Perak' 'Negeri Sembilan'
#  'W.P. Putrajaya' 'Pahang' 'Terengganu' 'W.P. Labuan']

# %%
# One hot encoding of covid_deaths_linelist
states = [
    "Malaysia"
    "Johor"
    "Kedah"
    "Kelantan"
    "Melaka"
    "Negeri Sembilan"
    "Pahang"
    "Perak"
    "Perlis"
    "Pulau Pinang"
    "Sabah"
    "Sarawak"
    "Selangor"
    "Terengganu"
    "W.P. Kuala Lumpur"
    "W.P. Labuan"
    "W.P. Putrajaya"
]
# Get dummies
encoded_covid_deaths = pd.get_dummies(covid_deaths, columns=["state"])
encoded_covid_cases = pd.get_dummies(covid_cases, columns=["state"])
# Convert dates to datetime format
date_cols_covid_deaths = encoded_covid_deaths.filter(like="date").columns
date_cols_covid_cases = encoded_covid_cases.filter(like="date").columns
encoded_covid_deaths[date_cols_covid_deaths] = encoded_covid_deaths[
    date_cols_covid_deaths
].apply(pd.to_datetime)
encoded_covid_cases[date_cols_covid_cases] = encoded_covid_cases[
    date_cols_covid_cases
].apply(pd.to_datetime)
df_covid_cases = encoded_covid_cases
df_covid_deaths = encoded_covid_deaths

# %% [markdown]
# #### Imputation

# %%
# Dropping dosage dates and brands as they take up a large proportion of the dataframe.
# df_covid_deaths.isnull().sum()
df_covid_deaths = df_covid_deaths.drop(
    columns=[
        "date_dose1",
        "date_dose2",
        "date_dose3",
        "brand1",
        "brand2",
        "brand3",
        "date",
        "date_positive",
    ]
)
df_covid_cases = df_covid_cases.drop(columns=["state_Malaysia"])

# %%
print(df_covid_cases.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33218 entries, 0 to 33217
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     33218 non-null  datetime64[ns]
#  1   cases_new                33218 non-null  int64
#  2   cases_import             33218 non-null  int64
#  3   cases_recovered          33218 non-null  int64
#  4   cases_active             33218 non-null  int64
#  5   cases_cluster            33218 non-null  int64
#  6   state_Johor              33218 non-null  bool
#  7   state_Kedah              33218 non-null  bool
#  8   state_Kelantan           33218 non-null  bool
#  9   state_Melaka             33218 non-null  bool
#  10  state_Negeri Sembilan    33218 non-null  bool
#  11  state_Pahang             33218 non-null  bool
#  12  state_Perak              33218 non-null  bool
#  13  state_Perlis             33218 non-null  bool
#  14  state_Pulau Pinang       33218 non-null  bool
#  15  state_Sabah              33218 non-null  bool
#  16  state_Sarawak            33218 non-null  bool
#  17  state_Selangor           33218 non-null  bool
#  18  state_Terengganu         33218 non-null  bool
#  19  state_W.P. Kuala Lumpur  33218 non-null  bool
#  20  state_W.P. Labuan        33218 non-null  bool
#  21  state_W.P. Putrajaya     33218 non-null  bool
# dtypes: bool(16), datetime64[ns](1), int64(5)
# memory usage: 2.0 MB
# None

# %%
print(df_covid_deaths.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37351 entries, 0 to 37350
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date_announced           37351 non-null  datetime64[ns]
#  1   age                      37351 non-null  int64
#  2   male                     37351 non-null  int64
#  3   bid                      37351 non-null  int64
#  4   malaysian                37351 non-null  int64
#  5   comorb                   37351 non-null  int64
#  6   state_Johor              37351 non-null  bool
#  7   state_Kedah              37351 non-null  bool
#  8   state_Kelantan           37351 non-null  bool
#  9   state_Melaka             37351 non-null  bool
#  10  state_Negeri Sembilan    37351 non-null  bool
#  11  state_Pahang             37351 non-null  bool
#  12  state_Perak              37351 non-null  bool
#  13  state_Perlis             37351 non-null  bool
#  14  state_Pulau Pinang       37351 non-null  bool
#  15  state_Sabah              37351 non-null  bool
#  16  state_Sarawak            37351 non-null  bool
#  17  state_Selangor           37351 non-null  bool
#  18  state_Terengganu         37351 non-null  bool
#  19  state_W.P. Kuala Lumpur  37351 non-null  bool
#  20  state_W.P. Labuan        37351 non-null  bool
#  21  state_W.P. Putrajaya     37351 non-null  bool
# dtypes: bool(16), datetime64[ns](1), int64(5)
# memory usage: 2.3 MB
# None

# %% [markdown]
# ### Splitting of Dataset into Train and Test Datasets

# %% [markdown]
# ##### Splitting dataset for covid cases and confusion matrix

# %%
# Feature Selection for Covid Deaths and Cases
X_cases = df_covid_cases.drop(columns=["date", "cases_new"])
y_cases = df_covid_cases["cases_new"]

# Temporal Split (Assuming sorted by date)
split = int(len(X_cases) * 0.8)
X_train_c, X_test_c = X_cases[:split], X_cases[split:]
y_train_c, y_test_c = y_cases[:split], y_cases[split:]

# %%
# Correlation heatmap of X_cases
plt.figure(figsize=(12, 10))
sns.heatmap(X_cases.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Matrix")
plt.show()

# %% [markdown]
# ##### Splitting dataset for covid_deaths

# %%
from sklearn.preprocessing import StandardScaler

# Separate Features and Target
X_deaths = df_covid_deaths.drop(columns=["date_announced", "bid"])
y_deaths = df_covid_deaths["bid"]

# Scale the 'age' column only to prevent gradient loss as the range of age is large.
scaler = StandardScaler()
X_deaths["age"] = scaler.fit_transform(X_deaths[["age"]])

# Stratified Split for individual data
X_train_d, X_test_d, y_train_d, y_test_d = train_test_split(
    X_deaths, y_deaths, test_size=0.2, stratify=y_deaths, random_state=42
)

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(X_deaths.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Matrix")
plt.show()

# %%
# Model Training for Covid Cases
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, r2_score

# Train
reg_model = XGBRegressor(n_estimators=1000, learning_rate=0.05, max_depth=6, n_jobs=1)
reg_model.fit(X_train_c, y_train_c, eval_set=[(X_test_c, y_test_c)], verbose=False)

# Evaluate
preds_c = reg_model.predict(X_test_c)

print(f"Mean Absolute Error: {mean_absolute_error(y_test_c, preds_c)}")
print(f"R2 Score: {r2_score(y_test_c, preds_c)}")  # Closer to 1.0 is better
# Out:
# Mean Absolute Error: 31.38361358642578
# R2 Score: 0.8597106337547302

# %%
# Model Training for Covid Deaths
from sklearn.ensemble import RandomForestClassifier


# Train
# Use 'balanced' because BID cases are usually a minority
clf_model = RandomForestClassifier(
    n_estimators=200, class_weight="balanced", n_jobs=6, random_state=42
)
clf_model.fit(X_train_d, y_train_d)

# Evaluate
preds_d = clf_model.predict(X_test_d)
print(confusion_matrix(y_test_d, preds_d))
print(classification_report(y_test_d, preds_d))
# Out:
# [[4599 1283]
#  [ 880  709]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81      5882
#            1       0.36      0.45      0.40      1589
#
#     accuracy                           0.71      7471
#    macro avg       0.60      0.61      0.60      7471
# weighted avg       0.74      0.71      0.72      7471

# %%
# Evaluation
import matplotlib.pyplot as plt

importances = clf_model.feature_importances_
indices = X_deaths.columns
plt.barh(indices, importances)
plt.title("Feature Importance - Deaths Model")
plt.show()

# %%
import matplotlib.pyplot as plt

importances = clf_model.feature_importances_
indices = X_cases.columns
plt.barh(indices, importances)
plt.title("Feature Importance - Deaths Model")
plt.show()

# %% [markdown]
# #### Importation of sci-kit learn models

# %%
import joblib

# Save the Cases Regressor
joblib.dump(reg_model, "cases_model.pkl")

# Save the Deaths Classifier
joblib.dump(clf_model, "deaths_model.pkl")

# IMPORTANT: Save the Scaler if you used one for Age
joblib.dump(scaler, "age_scaler.pkl")
# Out:
# ['age_scaler.pkl']

# %% [markdown]
# # Deep Modeling Based on Train, Test Split

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# For Cases (Regression)
X_train_c = X_train_c.astype("float32")
y_train_c = y_train_c.astype("float32")

# For Deaths (Classification)
X_train_d = X_train_d.astype("float32")
y_train_d = y_train_d.astype("float32")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777549332.149940  265894 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1777549332.150317  265894 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1777549332.175920  265894 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777549333.669768  265894 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1777549333.670022  265894 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
model_cases = models.Sequential(
    [
        layers.Input(shape=(X_train_c.shape[1],)),
        layers.Dense(64, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(1),  # No activation for regression
    ]
)

model_cases.compile(optimizer="SGD", loss="mse", metrics=["mae", "accuracy"])

# Train
model_cases.fit(X_train_c, y_train_c, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# E0000 00:00:1777549334.761318  265894 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 2/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 3/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 985us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 4/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 5/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 6/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 993us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 7/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 8/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 9/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 10/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 11/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 952us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 12/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 914us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 13/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 881us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 14/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 976us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 15/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 16/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 951us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 17/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 989us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 18/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 990us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 19/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 964us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 20/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 991us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 21/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 976us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 22/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 958us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 23/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 24/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 25/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 26/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 948us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 27/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 965us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 28/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 915us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 29/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 988us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 30/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 31/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 32/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 994us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 33/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 34/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 35/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 36/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 37/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 958us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 38/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 928us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 39/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 40/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 935us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 41/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 42/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 43/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 44/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 45/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 46/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 904us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 47/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 895us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 48/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 49/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 955us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan
# Epoch 50/50
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1s 995us/step - accuracy: 0.1381 - loss: nan - mae: nan - val_accuracy: 0.1229 - val_loss: nan - val_mae: nan

# %%
model_deaths = models.Sequential(
    [
        layers.Input(shape=(X_train_d.shape[1],)),
        layers.Dense(64, activation="relu"),
        layers.Dropout(0.2),  # Prevents overfitting
        layers.Dense(32, activation="relu"),
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid"),  # Sigmoid for 0/1 probability
    ]
)

# Use BinaryCrossentropy for 0/1 targets
model_deaths.compile(optimizer="SGD", loss="binary_crossentropy", metrics=["accuracy"])

# Train
model_deaths.fit(X_train_d, y_train_d, epochs=50, batch_size=64, validation_split=0.2)
        layers.Dense(16, activation="relu"),
# Out:
# Epoch 1/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7827 - loss: 0.5242 - val_accuracy: 0.7895 - val_loss: 0.4974
# Epoch 2/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7868 - loss: 0.4993 - val_accuracy: 0.7895 - val_loss: 0.4921
# Epoch 3/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7869 - loss: 0.4937 - val_accuracy: 0.7887 - val_loss: 0.4875
# Epoch 4/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7874 - loss: 0.4890 - val_accuracy: 0.7887 - val_loss: 0.4840
# Epoch 5/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7869 - loss: 0.4867 - val_accuracy: 0.7877 - val_loss: 0.4812
# Epoch 6/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7871 - loss: 0.4842 - val_accuracy: 0.7897 - val_loss: 0.4792
# Epoch 7/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7874 - loss: 0.4833 - val_accuracy: 0.7888 - val_loss: 0.4778
# Epoch 8/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7867 - loss: 0.4823 - val_accuracy: 0.7892 - val_loss: 0.4767
# Epoch 9/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7895 - loss: 0.4804 - val_accuracy: 0.7902 - val_loss: 0.4759
# Epoch 10/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7897 - loss: 0.4803 - val_accuracy: 0.7900 - val_loss: 0.4756
# Epoch 11/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7905 - loss: 0.4782 - val_accuracy: 0.7908 - val_loss: 0.4747
# Epoch 12/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7897 - loss: 0.4794 - val_accuracy: 0.7917 - val_loss: 0.4742
# Epoch 13/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7905 - loss: 0.4795 - val_accuracy: 0.7917 - val_loss: 0.4739
# Epoch 14/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7926 - loss: 0.4781 - val_accuracy: 0.7917 - val_loss: 0.4735
# Epoch 15/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7911 - loss: 0.4783 - val_accuracy: 0.7912 - val_loss: 0.4733
# Epoch 16/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7911 - loss: 0.4789 - val_accuracy: 0.7918 - val_loss: 0.4731
# Epoch 17/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7925 - loss: 0.4770 - val_accuracy: 0.7913 - val_loss: 0.4732
# Epoch 18/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7921 - loss: 0.4763 - val_accuracy: 0.7915 - val_loss: 0.4727
# Epoch 19/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7922 - loss: 0.4760 - val_accuracy: 0.7917 - val_loss: 0.4723
# Epoch 20/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7935 - loss: 0.4766 - val_accuracy: 0.7912 - val_loss: 0.4722
# Epoch 21/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7933 - loss: 0.4754 - val_accuracy: 0.7917 - val_loss: 0.4720
# Epoch 22/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7930 - loss: 0.4754 - val_accuracy: 0.7917 - val_loss: 0.4719
# Epoch 23/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7941 - loss: 0.4755 - val_accuracy: 0.7913 - val_loss: 0.4722
# Epoch 24/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7928 - loss: 0.4750 - val_accuracy: 0.7917 - val_loss: 0.4717
# Epoch 25/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7924 - loss: 0.4746 - val_accuracy: 0.7918 - val_loss: 0.4716
# Epoch 26/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7933 - loss: 0.4749 - val_accuracy: 0.7920 - val_loss: 0.4715
# Epoch 27/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7942 - loss: 0.4741 - val_accuracy: 0.7917 - val_loss: 0.4714
# Epoch 28/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7931 - loss: 0.4742 - val_accuracy: 0.7923 - val_loss: 0.4713
# Epoch 29/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7934 - loss: 0.4736 - val_accuracy: 0.7932 - val_loss: 0.4715
# Epoch 30/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7917 - loss: 0.4736 - val_accuracy: 0.7928 - val_loss: 0.4712
# Epoch 31/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7935 - loss: 0.4741 - val_accuracy: 0.7930 - val_loss: 0.4711
# Epoch 32/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7932 - loss: 0.4745 - val_accuracy: 0.7917 - val_loss: 0.4715
# Epoch 33/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7941 - loss: 0.4734 - val_accuracy: 0.7930 - val_loss: 0.4709
# Epoch 34/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7936 - loss: 0.4736 - val_accuracy: 0.7927 - val_loss: 0.4709
# Epoch 35/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7936 - loss: 0.4740 - val_accuracy: 0.7923 - val_loss: 0.4709
# Epoch 36/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7930 - loss: 0.4736 - val_accuracy: 0.7927 - val_loss: 0.4709
# Epoch 37/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7938 - loss: 0.4738 - val_accuracy: 0.7917 - val_loss: 0.4711
# Epoch 38/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7934 - loss: 0.4732 - val_accuracy: 0.7922 - val_loss: 0.4708
# Epoch 39/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7931 - loss: 0.4741 - val_accuracy: 0.7920 - val_loss: 0.4707
# Epoch 40/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7944 - loss: 0.4731 - val_accuracy: 0.7918 - val_loss: 0.4708
# Epoch 41/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7939 - loss: 0.4729 - val_accuracy: 0.7917 - val_loss: 0.4710
# Epoch 42/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7947 - loss: 0.4733 - val_accuracy: 0.7922 - val_loss: 0.4706
# Epoch 43/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7929 - loss: 0.4729 - val_accuracy: 0.7922 - val_loss: 0.4710
# Epoch 44/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7943 - loss: 0.4723 - val_accuracy: 0.7917 - val_loss: 0.4707
# Epoch 45/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7948 - loss: 0.4728 - val_accuracy: 0.7917 - val_loss: 0.4708
# Epoch 46/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7938 - loss: 0.4731 - val_accuracy: 0.7920 - val_loss: 0.4707
# Epoch 47/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7941 - loss: 0.4725 - val_accuracy: 0.7920 - val_loss: 0.4706
# Epoch 48/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7956 - loss: 0.4724 - val_accuracy: 0.7922 - val_loss: 0.4710
# Epoch 49/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7947 - loss: 0.4721 - val_accuracy: 0.7918 - val_loss: 0.4706
# Epoch 50/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7952 - loss: 0.4718 - val_accuracy: 0.7918 - val_loss: 0.4705

# %% [markdown]
# #### Saving keras models

# %%
model_deaths.save("deaths_model.keras")
model_cases.save("case_model.keras")
